# %%
import json
import pandas as pd
from pathlib import Path
import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
data = []
datasets = ["dblp-ref-0.json"]


for dataset in datasets:
    with open(Path("datasets") / dataset, "r") as f:
        for line in f:
            data.append(json.loads(line))

# %%
df = pd.DataFrame(data)
print(df.head())
print(df.shape)
# Out:
#                                             abstract  \
# 0  The purpose of this study is to develop a lear...
# 1  This paper describes the design and implementa...
# 2  This article applied GARCH model instead AR or...
# 3                                                NaN
# 4                                                NaN
#
#                                              authors  n_citation  \
# 0  [Makoto Satoh, Ryo Muramatsu, Mizue Kayama, Ka...           0
# 1                        [Gareth Beale, Graeme Earl]          50
# 2  [Altaf Hossain, Faisal Zaman, Mohammed Nasser,...          50
# 3  [Jea-Bum Park, Byungmok Kim, Jian Shen, Sun-Yo...           0
# 4                [Giovanna Guerrini, Isabella Merlo]           2
#
#                                           references  \
# 0  [51c7e02e-f5ed-431a-8cf5-f761f266d4be, 69b625b...
# 1  [10482dd3-4642-4193-842f-85f3b70fcf65, 3133714...
# 2  [2d84c0f2-e656-4ce7-b018-90eda1c132fe, a083a1b...
# 3  [8c78e4b0-632b-4293-b491-85b1976675e6, 9cdc54f...
# 4                                                NaN
#
#                                                title  \
# 0  Preliminary Design of a Network Protocol Learn...
# 1  A methodology for the physically accurate visu...
# 2  Comparison of GARCH, Neural Network and Suppor...
# 3  Development of Remote Monitoring and Control D...
# 4  Reasonig about Set-Oriented Methods in Object ...
#
#                                                venue  year  \
# 0  international conference on human-computer int...  2013
# 1            visual analytics science and technology  2011
# 2       pattern recognition and machine intelligence  2009
# 3                                                     2011
# 4                                                     1998
#
#                                      id
# 0  00127ee2-cb05-48ce-bc49-9de556b93346
# 1  001c58d3-26ad-46b3-ab3a-c1e557d16821
# 2  001c8744-73c4-4b04-9364-22d31a10dbf1
# 3  00338203-9eb3-40c5-9f31-cbac73a519ec
# 4  0040b022-1472-4f70-a753-74832df65266
# (1000000, 8)

# %%
# Remove entries with missing or empty title or venue
required_cols = ["title", "venue"]
df = df.dropna(subset=required_cols)

for col in ["title", "venue"]:
    df[col] = df[col].astype(str).str.strip()
    df = df[df[col] != ""]

# Remove entries where venue contains "arxiv"
mask_arxiv = df["venue"].str.contains("arxiv", case=False, na=False)
df = df[~mask_arxiv].copy()

# Filter venues with at least min_papers_per_venue papers
min_papers_per_venue = 1000

venue_counts = df["venue"].value_counts()
selected_venues = venue_counts[venue_counts >= min_papers_per_venue].index

venue_df = df[df["venue"].isin(selected_venues)].copy()


print(df.shape)
print(df.head())
# Out:
# (767565, 8)
#                                             abstract  \
# 0  The purpose of this study is to develop a lear...
# 1  This paper describes the design and implementa...
# 2  This article applied GARCH model instead AR or...
# 5                                                NaN
# 7                                                NaN
#
#                                              authors  n_citation  \
# 0  [Makoto Satoh, Ryo Muramatsu, Mizue Kayama, Ka...           0
# 1                        [Gareth Beale, Graeme Earl]          50
# 2  [Altaf Hossain, Faisal Zaman, Mohammed Nasser,...          50
# 5  [Rafael Álvarez, Leandro Tortosa, José-Francis...           0
# 7   [Guzin Ulutas, Mustafa Ulutas, Vasif V. Nabiyev]           0
#
#                                           references  \
# 0  [51c7e02e-f5ed-431a-8cf5-f761f266d4be, 69b625b...
# 1  [10482dd3-4642-4193-842f-85f3b70fcf65, 3133714...
# 2  [2d84c0f2-e656-4ce7-b018-90eda1c132fe, a083a1b...
# 5                                                NaN
# 7  [5626736c-e434-4e2d-8405-54940fab88ab, 8e87e87...
#
#                                                title  \
# 0  Preliminary Design of a Network Protocol Learn...
# 1  A methodology for the physically accurate visu...
# 2  Comparison of GARCH, Neural Network and Suppor...
# 5  COMPARING GNG3D AND QUADRIC ERROR METRICS METH...
# 7  Improved Secret Image Sharing Method By Encodi...
#
#                                                venue  year  \
# 0  international conference on human-computer int...  2013
# 1            visual analytics science and technology  2011
# 2       pattern recognition and machine intelligence  2009
# 5  international conference on computer graphics ...  2009
# 7  international symposium on computer and inform...  2011
#
#                                      id
# 0  00127ee2-cb05-48ce-bc49-9de556b93346
# 1  001c58d3-26ad-46b3-ab3a-c1e557d16821
# 2  001c8744-73c4-4b04-9364-22d31a10dbf1
# 5  005ce28f-ed77-4e97-afdc-a296137186a1
# 7  00701b05-684f-45f9-b281-425abfec482c

# %%
# Combine title into one text field per paper
venue_df["text"] = venue_df["title"] + " "

venue_text = (
    venue_df
    .groupby("venue")["text"]
    .apply(lambda s: " ".join(s))
    .reset_index()
)

tfidf = TfidfVectorizer(
    max_features=1000,
    stop_words="english"
)

X_venue = tfidf.fit_transform(venue_text["text"])
feature_names = tfidf.get_feature_names_out()
print(feature_names)



row_sums = np.asarray(X_venue.sum(axis=1)).ravel()
non_empty_mask = row_sums > 0

venue_text = venue_text[non_empty_mask].reset_index(drop=True)
X_venue = X_venue[non_empty_mask]

print(X_venue.shape)
# Out:
# ['2d' '3d' '802' 'abstract' 'access' 'accuracy' 'accurate' 'acoustic'
#  'acquisition' 'action' 'active' 'activity' 'ad' 'adaptation' 'adaptive'
#  'advanced' 'agent' 'agents' 'aggregation' 'aided' 'algebra' 'algebraic'
#  'algorithm' 'algorithms' 'alignment' 'allocation' 'analog' 'analysis'
#  'analyzing' 'annotation' 'ant' 'antenna' 'application' 'applications'
#  'applied' 'applying' 'approach' 'approaches' 'approximate'
#  'approximation' 'arbitrary' 'architecture' 'architectures' 'area' 'array'
#  'arrays' 'artificial' 'aspects' 'assembly' 'assessment' 'assignment'
#  'assisted' 'association' 'asymptotic' 'asynchronous' 'attribute' 'audio'
#  'augmented' 'authentication' 'automata' 'automated' 'automatic'
#  'autonomous' 'aware' 'balancing' 'band' 'bandwidth' 'base' 'based'
#  'basis' 'bayesian' 'beamforming' 'behavior' 'behaviour' 'belief' 'best'
#  'binary' 'bit' 'blind' 'block' 'body' 'boolean' 'bound' 'boundary'
#  'bounded' 'bounds' 'brain' 'brief' 'broadcast' 'building' 'business'
#  'cache' 'calculus' 'calibration' 'camera' 'capacity' 'case' 'causal'
#  'cdma' 'cell' 'cellular' 'chain' 'challenges' 'change' 'changes'
#  'channel' 'channels' 'chaotic' 'characteristics' 'characterization'
#  'checking' 'chinese' 'chip' 'circuit' 'circuits' 'class' 'classes'
#  'classification' 'classifier' 'classifiers' 'closed' 'cloud' 'cluster'
#  'clustering' 'clusters' 'cmos' 'code' 'coded' 'codes' 'coding'
#  'cognitive' 'collaboration' 'collaborative' 'colony' 'color'
#  'combination' 'combinatorial' 'combined' 'combining' 'commerce' 'common'
#  'communication' 'communications' 'community' 'compact' 'comparative'
#  'comparing' 'comparison' 'compensation' 'complete' 'complex' 'complexity'
#  'component' 'components' 'composition' 'compressed' 'compression'
#  'computation' 'computational' 'computations' 'computer' 'computing'
#  'concept' 'concepts' 'conceptual' 'concurrent' 'conditional' 'conditions'
#  'configuration' 'connected' 'connectivity' 'consistency' 'constant'
#  'constrained' 'constraint' 'constraints' 'constructing' 'construction'
#  'content' 'context' 'continuous' 'contour' 'control' 'controlled'
#  'controller' 'convergence' 'conversion' 'convex' 'cooperation'
#  'cooperative' 'coordination' 'core' 'corpus' 'correction' 'correlated'
#  'correlation' 'cost' 'coupled' 'criteria' 'criterion' 'critical' 'cross'
#  'current' 'cycle' 'cycles' 'cyclic' 'data' 'database' 'databases'
#  'decentralized' 'decision' 'decoding' 'decomposition' 'deep' 'degree'
#  'delay' 'delays' 'delivery' 'demand' 'dense' 'density' 'dependent'
#  'depth' 'der' 'description' 'design' 'designing' 'designs' 'detecting'
#  'detection' 'determination' 'deterministic' 'developing' 'development'
#  'device' 'devices' 'diagnosis' 'dialogue' 'difference' 'different'
#  'differential' 'diffusion' 'digital' 'dimensional' 'direct' 'directed'
#  'directional' 'discovery' 'discrete' 'discriminant' 'discriminative'
#  'display' 'distance' 'distortion' 'distributed' 'distribution'
#  'distributions' 'diversity' 'dna' 'document' 'documents' 'domain'
#  'domains' 'double' 'downlink' 'driven' 'dual' 'dynamic' 'dynamical'
#  'dynamics' 'early' 'edge' 'education' 'eeg' 'effect' 'effective'
#  'effects' 'efficiency' 'efficient' 'electronic' 'element' 'embedded'
#  'embedding' 'emotion' 'empirical' 'encoding' 'end' 'energy' 'engine'
#  'engineering' 'english' 'enhanced' 'enhancement' 'enhancing' 'ensemble'
#  'enterprise' 'entropy' 'environment' 'environments' 'equalization'
#  'equation' 'equations' 'error' 'errors' 'estimating' 'estimation'
#  'evaluating' 'evaluation' 'event' 'evidence' 'evolution' 'evolutionary'
#  'evolving' 'exact' 'execution' 'experience' 'experimental' 'experiments'
#  'expert' 'exploiting' 'exploration' 'exploring' 'exponential'
#  'expression' 'extended' 'extending' 'extension' 'extracting' 'extraction'
#  'face' 'facial' 'factor' 'factorization' 'factors' 'fading' 'failure'
#  'fast' 'fault' 'feature' 'features' 'feedback' 'field' 'fields' 'filter'
#  'filtering' 'filters' 'finding' 'finite' 'fixed' 'flexible' 'flow'
#  'flows' 'fmri' 'force' 'forecasting' 'form' 'formal' 'formation'
#  'forward' 'fractional' 'frame' 'framework' 'free' 'frequency' 'fully'
#  'function' 'functional' 'functions' 'fusion' 'future' 'fuzzy' 'gain'
#  'game' 'games' 'gaussian' 'gene' 'general' 'generalization' 'generalized'
#  'generating' 'generation' 'generic' 'genetic' 'geometric' 'geometry'
#  'global' 'gpu' 'gradient' 'graph' 'graphical' 'graphs' 'grid' 'grids'
#  'group' 'groups' 'guided' 'hand' 'handling' 'hardware' 'health'
#  'heterogeneous' 'heuristic' 'heuristics' 'hidden' 'hierarchical' 'high'
#  'higher' 'highly' 'hmm' 'hoc' 'home' 'human' 'hybrid' 'identification'
#  'identifying' 'ieee' 'ii' 'image' 'images' 'imaging' 'impact'
#  'implementation' 'implementing' 'implicit' 'improve' 'improved'
#  'improvement' 'improving' 'incremental' 'independent' 'index' 'indexing'
#  'indoor' 'induced' 'induction' 'industrial' 'industry' 'inference'
#  'infinite' 'influence' 'information' 'infrastructure' 'input' 'inspired'
#  'integer' 'integral' 'integrated' 'integrating' 'integration'
#  'intelligence' 'intelligent' 'inter' 'interaction' 'interactions'
#  'interactive' 'interface' 'interfaces' 'interference' 'internet'
#  'interpolation' 'interpretation' 'interval' 'introduction' 'invariant'
#  'inverse' 'investigation' 'ip' 'issues' 'iterative' 'japanese' 'java'
#  'joint' 'kernel' 'key' 'knowledge' 'language' 'languages' 'large'
#  'lattice' 'layer' 'learning' 'length' 'level' 'life' 'light' 'like'
#  'likelihood' 'limited' 'line' 'linear' 'linguistic' 'link' 'load' 'local'
#  'localization' 'location' 'logic' 'logics' 'long' 'loop' 'low' 'lower'
#  'lte' 'machine' 'machines' 'magnetic' 'maintenance' 'making' 'management'
#  'managing' 'manipulation' 'manufacturing' 'map' 'mapping' 'maps' 'market'
#  'markov' 'matching' 'mathematical' 'matrices' 'matrix' 'max' 'maximum'
#  'mean' 'means' 'measure' 'measurement' 'measurements' 'measures'
#  'measuring' 'mechanism' 'mechanisms' 'media' 'medical' 'memory' 'mesh'
#  'message' 'meta' 'method' 'methodology' 'methods' 'metric' 'metrics'
#  'micro' 'mimo' 'minimal' 'minimization' 'minimum' 'mining' 'mixed'
#  'mixture' 'mobile' 'mobility' 'modal' 'mode' 'model' 'modeling'
#  'modelling' 'models' 'modified' 'modular' 'modulation' 'molecular'
#  'monitoring' 'motion' 'moving' 'mpi' 'mri' 'multi' 'multicast'
#  'multidimensional' 'multimedia' 'multimodal' 'multiple' 'multiuser'
#  'music' 'mutual' 'natural' 'navigation' 'near' 'nearest' 'net' 'nets'
#  'network' 'networks' 'neural' 'new' 'news' 'node' 'noise' 'noisy' 'non'
#  'nonlinear' 'note' 'novel' 'number' 'numbers' 'numerical' 'object'
#  'objective' 'objects' 'ofdm' 'online' 'ontologies' 'ontology' 'open'
#  'operations' 'operator' 'operators' 'optical' 'optimal' 'optimization'
#  'optimized' 'optimizing' 'order' 'organization' 'organizational'
#  'organizing' 'orientation' 'oriented' 'orthogonal' 'output' 'packet'
#  'paper' 'parallel' 'parameter' 'parameters' 'parametric' 'partial'
#  'particle' 'partitioning' 'path' 'paths' 'pattern' 'patterns' 'peer'
#  'people' 'perception' 'performance' 'periodic' 'personal' 'perspective'
#  'petri' 'phase' 'physical' 'placement' 'planar' 'plane' 'planning'
#  'platform' 'point' 'points' 'policy' 'polynomial' 'population' 'pose'
#  'position' 'positive' 'potential' 'power' 'practical' 'practice' 'pre'
#  'predicting' 'prediction' 'predictive' 'preliminary' 'presence'
#  'preserving' 'privacy' 'probabilistic' 'probability' 'problem' 'problems'
#  'procedure' 'process' 'processes' 'processing' 'processor' 'product'
#  'production' 'products' 'program' 'programming' 'programs' 'project'
#  'projection' 'projects' 'proof' 'propagation' 'properties' 'protection'
#  'protein' 'protocol' 'protocols' 'public' 'qos' 'quadratic' 'qualitative'
#  'quality' 'quantitative' 'quantization' 'quantum' 'quasi' 'queries'
#  'query' 'radar' 'radio' 'random' 'range' 'rank' 'ranking' 'rate' 'real'
#  'reality' 'reasoning' 'receiver' 'recognition' 'recommendation'
#  'reconfigurable' 'reconstruction' 'recovery' 'recurrent' 'recursive'
#  'reduced' 'reducing' 'reduction' 'reference' 'refinement' 'region'
#  'regions' 'registration' 'regression' 'regular' 'reinforcement' 'related'
#  'relation' 'relational' 'relations' 'relationship' 'relay' 'reliability'
#  'reliable' 'remote' 'representation' 'representations' 'requirements'
#  'research' 'resolution' 'resource' 'resources' 'response' 'results'
#  'retrieval' 'reuse' 'review' 'risk' 'robot' 'robotic' 'robots' 'robust'
#  'robustness' 'role' 'rough' 'routing' 'rule' 'rules' 'sampling' 'sar'
#  'satellite' 'satisfaction' 'scalable' 'scale' 'scaling' 'scene'
#  'scheduling' 'scheme' 'schemes' 'science' 'scientific' 'search'
#  'searching' 'second' 'secure' 'security' 'segmentation' 'selection'
#  'selective' 'self' 'semantic' 'semantics' 'semi' 'sensing' 'sensitive'
#  'sensitivity' 'sensor' 'sensors' 'separation' 'sequence' 'sequences'
#  'sequential' 'series' 'server' 'service' 'services' 'set' 'sets' 'shape'
#  'shared' 'sharing' 'short' 'signal' 'signals' 'similarity' 'simple'
#  'simulation' 'simulations' 'simultaneous' 'single' 'size' 'small' 'smart'
#  'social' 'soft' 'software' 'solution' 'solutions' 'solving' 'sound'
#  'source' 'sources' 'space' 'spaces' 'sparse' 'spatial' 'spatio' 'speaker'
#  'special' 'specific' 'specification' 'specifications' 'spectral'
#  'spectrum' 'speech' 'speed' 'spoken' 'squares' 'stability'
#  'stabilization' 'stable' 'stage' 'standard' 'state' 'static'
#  'statistical' 'statistics' 'step' 'stereo' 'stochastic' 'storage'
#  'strategies' 'strategy' 'stream' 'streaming' 'streams' 'structural'
#  'structure' 'structured' 'structures' 'studies' 'study' 'sub' 'subspace'
#  'sum' 'super' 'supervised' 'supply' 'support' 'supporting' 'surface'
#  'surfaces' 'survey' 'svm' 'swarm' 'switched' 'switching' 'symbolic'
#  'symmetric' 'synchronization' 'synthesis' 'systems' 'target' 'task'
#  'tasks' 'tcp' 'teaching' 'technical' 'technique' 'techniques'
#  'technologies' 'technology' 'temperature' 'temporal' 'tensor' 'term'
#  'test' 'testing' 'text' 'texture' 'theorem' 'theoretic' 'theoretical'
#  'theory' 'threshold' 'throughput' 'time' 'timing' 'tolerant' 'tool'
#  'tools' 'topic' 'topological' 'topology' 'total' 'tracking' 'traffic'
#  'training' 'trajectory' 'transfer' 'transform' 'transformation'
#  'transformations' 'translation' 'transmission' 'transport' 'tree' 'trees'
#  'trust' 'tuning' 'type' 'types' 'ubiquitous' 'uml' 'uncertain'
#  'uncertainty' 'und' 'understanding' 'unified' 'uniform' 'unit'
#  'universal' 'unknown' 'unsupervised' 'urban' 'usability' 'usage' 'use'
#  'user' 'users' 'using' 'validation' 'value' 'valued' 'variable'
#  'variables' 'variational' 'varying' 'vector' 'vehicle' 'verification'
#  'versus' 'video' 'view' 'virtual' 'vision' 'visual' 'visualization'
#  'vlsi' 'voice' 'voltage' 'volume' 'von' 'vs' 'water' 'watermarking'
#  'wave' 'wavelet' 'way' 'web' 'weight' 'weighted' 'wide' 'wireless' 'word'
#  'words' 'work' 'workflow' 'world' 'xml' 'zero']
# (127, 1000)

# %%
# Convert sparse TF-IDF matrix to dense
X_dense = X_venue.toarray()

# Z-score normalization (mean 0, variance 1 for each feature)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_dense)

k = 30
kmeans = KMeans(
    n_clusters=k,
    random_state=42,
    n_init=10
)

cluster_labels = kmeans.fit_predict(X_scaled)

# Attach cluster labels back to the venues
venue_text["cluster"] = cluster_labels
print(venue_text.head())

pca = PCA(n_components=2, random_state=42)
X_pca_2d = pca.fit_transform(X_scaled)

# Store coordinates if you want to inspect later
venue_text["pc1"] = X_pca_2d[:, 0]
venue_text["pc2"] = X_pca_2d[:, 1]

# Example: reduce to 50 dims for clustering
pca_50 = PCA(n_components=50, random_state=42)
X_pca_50 = pca_50.fit_transform(X_scaled)

kmeans = KMeans(n_clusters=30, random_state=42, n_init=10)
cluster_labels = kmeans.fit_predict(X_pca_50)

venue_text["cluster"] = cluster_labels

# Then a second PCA to 2D just for plotting:
pca_vis = PCA(n_components=2, random_state=42)
X_pca_2d = pca_vis.fit_transform(X_pca_50)
venue_text["pc1"] = X_pca_2d[:, 0]
venue_text["pc2"] = X_pca_2d[:, 1]
